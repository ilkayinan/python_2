# %%
print("merhaba \nbenim adım ilkay inan")
print("benim adım \tilkay")
# Out:
# merhaba
# benim adım ilkay inan
# benim adım 	ilkay

# %%
print("benim  adım {}".format("ilkay"))
print("benim  adım {} yasım {}".format("ilkay", 36))
print("benim  adım {0} yasım {1}".format("ilkay", 36))
print("benim  adım {1} yasım {0}".format("ilkay", 36))
print("benim  adım {ad} yasım {yas}".format(ad="ilkay", yas=36))
print("benim  adım {ad} yasım {yas}".format(yas=36, ad="ilkay"))
# Out:
# benim  adım ilkay
# benim  adım ilkay yasım 36
# benim  adım ilkay yasım 36
# benim  adım 36 yasım ilkay
# benim  adım ilkay yasım 36
# benim  adım ilkay yasım 36
